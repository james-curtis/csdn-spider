# %%
import pymongo

client = pymongo.MongoClient("mongodb://127.0.0.1:27017/")
db = client["spider"]

# %%
from pyecharts.globals import CurrentConfig, NotebookType

CurrentConfig.NOTEBOOK_TYPE = NotebookType.JUPYTER_LAB

# %%
import pprint

# %%
"""
近期一百页推荐中男女发博客数量
"""
data = list(
    db.article.aggregate(
        [
            {
                "$lookup": {
                    "from": "user",
                    "localField": "user_name",
                    "foreignField": "user_name",
                    "as": "user",
                }
            },
            {"$unwind": {"path": "$user"}},
            {"$group": {"_id": "$user.sex", "count": {"$count": {}}}},
        ]
    )
)
pprint.pprint(data)
from pyecharts.charts import Bar

result = {}
for item in data:
    result[item["_id"]] = item["count"]

# from pyecharts import options as opts
# 近期一百页推荐中男女发博客数量
bar1 = Bar().add_xaxis(["男", "女"]).add_yaxis("发帖量", [result["male"], result["famale"]])
bar1.load_javascript()
# Out:
# [{'_id': 'famale', 'count': 856}, {'_id': 'male', 'count': 1101}]

# %%
bar1.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="af13d7177f66484e9e5a478ff7780724" class="chart-container" style="width:900px; height:500px;"></div>
#     <script>
#         var chart_af13d7177f66484e9e5a478ff7780724 = echarts.init(
#             document.getElementById('af13d7177f66484e9e5a478ff7780724'), 'white', {renderer: 'canvas'});
#         var option_af13d7177f66484e9e5a478ff7780724 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u53d1\u5e16\u91cf",
#             "legendHoverLink": true,
#             "data": [
#                 1101,
#                 856
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u53d1\u5e16\u91cf"
#             ],
#             "selected": {
#                 "\u53d1\u5e16\u91cf": true
#             }
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u7537",
#                 "\u5973"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ]
# };
#         chart_af13d7177f66484e9e5a478ff7780724.setOption(option_af13d7177f66484e9e5a478ff7780724);
#     </script>
# </body>
# </html>

# %%
# %%html
# <img src="https://tva1.sinaimg.cn/large/008d89Swgy1h5sqdtm13cg30pk0dqwid.gif"/>
# Out:
# <img src="https://tva1.sinaimg.cn/large/008d89Swgy1h5sqdtm13cg30pk0dqwid.gif"/>

# %%
"""
码龄、发表博客量、性别关系
"""
from datetime import datetime

pipeline = [
    {
        "$addFields": {
            "join_time": {
                "$filter": {
                    "input": ["$join_time"],
                    "as": "d",
                    "cond": {"$ne": ["$$d", None]},
                }
            }
        }
    },
    {"$unwind": {"path": "$join_time"}},
    {
        "$addFields": {
            "join_time_date": {"$dateFromString": {"dateString": "$join_time"}}
        }
    },
    {
        "$addFields": {
            "join_year_util_now": {
                "$add": [
                    {
                        "$dateDiff": {
                            "startDate": "$join_time_date",
                            "endDate": datetime.now(),
                            "unit": "year",
                            "timezone": "Asia/Shanghai",
                        }
                    }
                ]
            }
        }
    },
    {
        "$group": {
            "_id": {"date": "$join_year_util_now", "sex": "$sex"},
            "count": {"$count": {}},
            "join_time": {"$first": "$join_time"},
        }
    },
    {"$addFields": {"sex": "$_id.sex", "join_year_util_now": "$_id.date"}},
    {"$sort": {"join_year_util_now": -1}},
    {
        "$addFields": {
            "sex": {
                "$filter": {
                    "input": ["$sex"],
                    "as": "s",
                    "cond": {"$ne": ["$$s", "famale"]},
                }
            }
        }
    },
    {"$unwind": {"path": "$sex"}},
    {
        "$addFields": {
            "sex": {
                "$filter": {
                    "input": ["$sex"],
                    "as": "s",
                    "cond": {"$ne": ["$$s", None]},
                }
            }
        }
    },
    {"$unwind": {"path": "$sex"}},
]

# %%
"""
码龄、发表博客量、性别关系
"""
import copy
male_data = list(db.user.aggregate(pipeline))
pipeline[-4]["$addFields"]["sex"]["$filter"]["cond"]["$ne"] = ["$$s", "male"]
famale_data = list(db.user.aggregate(pipeline))
data = list(db.user.aggregate(pipeline[0:-4]))

from pyecharts import options as opts
from pyecharts.charts import Line

xaxis = list(range(data[-1]["join_year_util_now"], data[0]["join_year_util_now"] + 1))

yaxis = []
for i in range(len(xaxis)):
    yaxis.append([i, 0, 0])
for item in data:
    yaxis[item["join_year_util_now"]][0] = item["join_year_util_now"]
    if item["sex"] == "male":
        yaxis[item["join_year_util_now"]][1] = item["count"]
    elif item["sex"] == "famale":
        yaxis[item["join_year_util_now"]][2] = item["count"]
dimensions = ["join_year_util_now", '男', '女']
source = [dimensions] + yaxis

pprint.pprint(source)
"""
pyecharts太垃圾了。用js版本的echarts很好
链接：https://echarts.apache.org/examples/zh/editor.html?c=line-smooth&code=PYBwLglsB2AEC8sDeAoWsA2BTA5l6AJgFzIC-ANGrGMMBpCCauumAE4Q55skDkAhgA8IAZ15UKVAvzD8RWMEyroRwAK5sAxlhIBtZS128AVsAjQA-gE8s_NhbWQMF6MADuvcrF6B2V0_fAZ01eAF1KFkMABi8AVgBmLwBGWIjQg3RdBMSE6JiANlTw9IAmLIBOLwAWWILC3XjYUqjYZJrw3QrEiMzmlLDanNgADkGvIuq-ttzK8obWwwB2L1ip2ATetNhdEdgi7YS59Jmx0YPNtcS904zuhO2Kq4SS1cXYdcKz-oSZ_YnDBI6dk03rVspVEg8VitgW0Ei8gQ9tvVoX9vl5kcUgWirkVuk99gZghI-oIAILCERMWDQfgAWx03kAgB6AEPz_GArCB6bxNDJcMA2FZeLBJOgrGTRJTqXS-IBF5UAFhGALWVAEXagAdTQXC2DyDhYCmbJDUdmcjDmLBqrx6tkcvhG6AmoWE0gAbiAA
"""

# line1 = Line().add_dataset(source).add_yaxis(series_name="男", y_axis=[]).add_yaxis(series_name="女", y_axis=[]).set_global_opts(
#         xaxis_opts=opts.AxisOpts(type_="category"),
#     )
# pprint.pprint(line1.dump_options())
# line1.render_notebook()
# Out:
# [['join_year_util_now', '男', '女'],
#  [0, 53, 130],
#  [1, 115, 56],
#  [2, 119, 43],
#  [3, 90, 30],
#  [4, 101, 30],
#  [5, 88, 23],
#  [6, 49, 9],
#  [7, 36, 10],
#  [8, 28, 1],
#  [9, 23, 2],
#  [10, 18, 1],
#  [11, 18, 4],
#  [12, 17, 0],
#  [13, 19, 1],
#  [14, 20, 0],
#  [15, 4, 1],
#  [16, 6, 0],
#  [17, 0, 0],
#  [18, 3, 0],
#  [19, 1, 0],
#  [20, 0, 0],
#  [21, 2, 1]]
# '\npyecharts太垃圾了。用js版本的echarts很好\n链接：https://echarts.apache.org/examples/zh/editor.html?c=line-smooth&code=PYBwLglsB2AEC8sDeAoWsA2BTA5l6AJgFzIC-ANGrGMMBpCCauumAE4Q55skDkAhgA8IAZ15UKVAvzD8RWMEyroRwAK5sAxlhIBtZS128AVsAjQA-gE8s_NhbWQMF6MADuvcrF6B2V0_fAZ01eAF1KFkMABi8AVgBmLwBGWIjQg3RdBMSE6JiANlTw9IAmLIBOLwAWWILC3XjYUqjYZJrw3QrEiMzmlLDanNgADkGvIuq-ttzK8obWwwB2L1ip2ATetNhdEdgi7YS59Jmx0YPNtcS904zuhO2Kq4SS1cXYdcKz-oSZ_YnDBI6dk03rVspVEg8VitgW0Ei8gQ9tvVoX9vl5kcUgWirkVuk99gZghI-oIAILCERMWDQfgAWx03kAgB6AEPz_GArCB6bxNDJcMA2FZeLBJOgrGTRJTqXS-IBF5UAFhGALWVAEXagAdTQXC2DyDhYCmbJDUdmcjDmLBqrx6tkcvhG6AmoWE0gAbiAA\n'

# %%
# %%html
# <img src="https://tva1.sinaimg.cn/large/008d89Swgy1h5spiylcakj30ui0lm0vo.jpg"/>
# <img src="https://tva1.sinaimg.cn/large/008d89Swgy1h5spkm5f7wg30uy0l8thy.gif"/>
# <img src="https://tva1.sinaimg.cn/large/008d89Swgy1h5spnfapqlj30ud0l7ac2.jpg"/>
# Out:
# <img src="https://tva1.sinaimg.cn/large/008d89Swgy1h5spiylcakj30ui0lm0vo.jpg"/>
# <img src="https://tva1.sinaimg.cn/large/008d89Swgy1h5spkm5f7wg30uy0l8thy.gif"/>
# <img src="https://tva1.sinaimg.cn/large/008d89Swgy1h5spnfapqlj30ud0l7ac2.jpg"/>

# %%
"""
发布博客量与发布地 地图
@link https://codesandbox.io/s/air-quality-forked-sk406u?from-embed

经纬度坐标太难找了，这里只显示了国内的
"""
data = db.article.aggregate([
    {
        "$lookup": {
            "from": "user",
            "localField": "user_name",
            "foreignField": "user_name",
            "as": "user"
        }
    },
    {
        "$unwind": {
            "path": "$user"
        }
    },
    {
        "$addFields": {
            "address": {
                "$filter": {
                    "input": [
                        "$user.ip_address"
                    ],
                    "as": "d",
                    "cond": {
                        "$ne": [
                            "$$d",
                             None
                        ]
                    }
                }
            }
        }
    },
    {
        "$unwind": {
            "path": "$address"
        }
    },
    {
        "$group": {
            "_id": "$address",
            "value": {
                "$count": {}
            },
            "name": {
                "$first": "$address"
            }
        }
    }
])
list(data)
# Out:
# [{'_id': '江苏省', 'value': 102, 'name': '江苏省'},
#  {'_id': '安徽省', 'value': 56, 'name': '安徽省'},
#  {'_id': '新加坡', 'value': 3, 'name': '新加坡'},
#  {'_id': '吉林省', 'value': 14, 'name': '吉林省'},
#  {'_id': '云南省', 'value': 8, 'name': '云南省'},
#  {'_id': '青海省', 'value': 2, 'name': '青海省'},
#  {'_id': '台湾省', 'value': 1, 'name': '台湾省'},
#  {'_id': '宁夏', 'value': 2, 'name': '宁夏'},
#  {'_id': '内蒙古', 'value': 3, 'name': '内蒙古'},
#  {'_id': '天津市', 'value': 26, 'name': '天津市'},
#  {'_id': '上海市', 'value': 63, 'name': '上海市'},
#  {'_id': '广东省', 'value': 409, 'name': '广东省'},
#  {'_id': '陕西省', 'value': 79, 'name': '陕西省'},
#  {'_id': '香港', 'value': 10, 'name': '香港'},
#  {'_id': '日本', 'value': 2, 'name': '日本'},
#  {'_id': '河南省', 'value': 50, 'name': '河南省'},
#  {'_id': '辽宁省', 'value': 18, 'name': '辽宁省'},
#  {'_id': '美国', 'value': 3, 'name': '美国'},
#  {'_id': '中国', 'value': 2, 'name': '中国'},
#  {'_id': '黑龙江省', 'value': 16, 'name': '黑龙江省'},
#  {'_id': '北京市', 'value': 176, 'name': '北京市'},
#  {'_id': '四川省', 'value': 77, 'name': '四川省'},
#  {'_id': '山西省', 'value': 15, 'name': '山西省'},
#  {'_id': '广西', 'value': 25, 'name': '广西'},
#  {'_id': '江西省', 'value': 24, 'name': '江西省'},
#  {'_id': '福建省', 'value': 45, 'name': '福建省'},
#  {'_id': '山东省', 'value': 48, 'name': '山东省'},
#  {'_id': '河北省', 'value': 49, 'name': '河北省'},
#  {'_id': '湖南省', 'value': 144, 'name': '湖南省'},
#  {'_id': '新疆', 'value': 3, 'name': '新疆'},
#  {'_id': '重庆市', 'value': 41, 'name': '重庆市'},
#  {'_id': '贵州省', 'value': 9, 'name': '贵州省'},
#  {'_id': '浙江省', 'value': 63, 'name': '浙江省'},
#  {'_id': '加拿大', 'value': 1, 'name': '加拿大'},
#  {'_id': '甘肃省', 'value': 11, 'name': '甘肃省'},
#  {'_id': '湖北省', 'value': 42, 'name': '湖北省'}]

# %%
# %%html
# <img src='https://tva1.sinaimg.cn/large/008d89Swgy1h5spf3rftkj31hc0psalb.jpg' />
# <img src="https://tva1.sinaimg.cn/large/008d89Swgy1h5spju815pg31h80pohdt.gif"/>
# Out:
# <img src='https://tva1.sinaimg.cn/large/008d89Swgy1h5spf3rftkj31hc0psalb.jpg' />
# <img src="https://tva1.sinaimg.cn/large/008d89Swgy1h5spju815pg31h80pohdt.gif"/>

# %%
"""
文章tag词云
"""
data = db.article.aggregate([
    {
        "$project": {
            "tags": 1
        }
    },
    {
        "$addFields": {
            "tags": {
                "$filter": {
                    "input": [
                        "$tags"
                    ],
                    "as": "d",
                    "cond": {
                        "$ne": [
                            "$$d",
                            None
                        ]
                    }
                }
            }
        }
    },
    {
        "$unwind": {
            "path": "$tags"
        }
    },
    {
        "$project": {
            "_id": 0,
            "tags": 1
        }
    },
    {
        "$unwind": {
            "path": "$tags"
        }
    },
    {
        "$group": {
            "_id": "$tags",
            "value": {
                "$count": {}
            }
        }
    },
    {
        "$sort": {
            "value": -1
        }
    }
])
result = []
for item in data:
    result.append(tuple(item.values()))
pprint.pprint(result)
# Out:
# [('开发语言', 582),
#  ('java', 538),
#  ('前端', 248),
#  ('人工智能', 244),
#  ('运维', 190),
#  ('javascript', 181),
#  ('数据库', 179),
#  ('python', 171),
#  ('服务器', 169),
#  ('算法', 145),
#  ('机器学习', 130),
#  ('linux', 122),
#  ('深度学习', 121),
#  ('大数据', 121),
#  ('ecmascript', 113),
#  ('vue.js', 102),
#  ('spring', 99),
#  ('网络', 98),
#  ('spring boot', 98),
#  ('后端', 97),
#  ('mybatis', 88),
#  ('神经网络', 73),
#  ('mysql', 67),
#  ('职场和发展', 67),
#  ('面试', 66),
#  ('jvm', 65),
#  ('servlet', 62),
#  ('学习', 61),
#  ('c++', 58),
#  ('计算机视觉', 57),
#  ('docker', 52),
#  ('数据结构', 52),
#  ('嵌入式硬件', 50),
#  ('单片机', 48),
#  ('容器', 46),
#  ('html', 45),
#  ('前端框架', 44),
#  ('ide', 42),
#  ('分布式', 42),
#  ('redis', 39),
#  ('sql', 37),
#  ('缓存', 36),
#  ('elementui', 32),
#  ('css', 31),
#  ('leetcode', 31),
#  ('kubernetes', 30),
#  ('云原生', 29),
#  ('物联网', 29),
#  ('arm', 28),
#  ('dubbo', 27),
#  ('stm32', 27),
#  ('intellij-idea', 27),
#  ('数据挖掘', 26),
#  ('网络协议', 26),
#  ('android', 25),
#  ('安全', 24),
#  ('opencv', 22),
#  ('微服务', 22),
#  ('搜索引擎', 22),
#  ('elasticsearch', 21),
#  ('zookeeper', 19),
#  ('css3', 19),
#  ('github', 18),
#  ('git', 18),
#  ('java-zookeeper', 17),
#  ('matlab', 17),
#  ('maven', 17),
#  ('ubuntu', 17),
#  ('全文检索', 17),
#  ('windows', 15),
#  ('tcp/ip', 15),
#  ('html5', 15),
#  ('c#', 15),
#  ('web安全', 15),
#  ('qt', 15),
#  ('云计算', 14),
#  ('numpy', 14),
#  ('spring cloud', 14),
#  ('fpga开发', 14),
#  ('centos', 14),
#  ('c语言', 13),
#  ('json', 13),
#  ('hadoop', 13),
#  ('区块链', 13),
#  ('自动化', 12),
#  ('microsoft', 12),
#  ('npm', 12),
#  ('pytorch', 12),
#  ('比特币', 11),
#  ('数字货币', 11),
#  ('django', 11),
#  ('r语言', 11),
#  ('http', 11),
#  ('编辑器', 11),
#  ('react.js', 10),
#  ('排序算法', 10),
#  ('ui', 10),
#  ('游戏', 10),
#  ('cnn', 10),
#  ('bash', 10),
#  ('架构', 10),
#  ('链表', 9),
#  ('php', 9),
#  ('汽车', 9),
#  ('node.js', 9),
#  ('单元测试', 9),
#  ('nginx', 9),
#  ('小程序', 9),
#  ('.net', 8),
#  ('音视频', 8),
#  ('ios', 8),
#  ('vscode', 8),
#  ('微信', 8),
#  ('golang', 8),
#  ('android studio', 8),
#  ('爬虫', 8),
#  ('压力测试', 8),
#  ('数据分析', 8),
#  ('typescript', 7),
#  ('rabbitmq', 7),
#  ('阿里云', 7),
#  ('微信小程序', 7),
#  ('正则表达式', 7),
#  ('flask', 7),
#  ('tomcat', 7),
#  ('nosql', 6),
#  ('apache', 6),
#  ('目标检测', 6),
#  ('测试工具', 6),
#  ('测试用例', 6),
#  ('java-rabbitmq', 6),
#  ('macos', 5),
#  ('eureka', 5),
#  ('图像处理', 5),
#  ('自然语言处理', 5),
#  ('unix', 5),
#  ('xcode', 5),
#  ('语音识别', 5),
#  ('游戏引擎', 5),
#  ('ajax', 5),
#  ('开源', 5),
#  ('哈希算法', 5),
#  ('unity', 5),
#  ('聚类', 5),
#  ('arm开发', 5),
#  ('web3', 5),
#  ('oracle', 5),
#  ('分类', 5),
#  ('华为', 4),
#  ('es6', 4),
#  ('chrome', 4),
#  ('flutter', 4),
#  ('3d', 4),
#  ('junit', 4),
#  ('深度优先', 4),
#  ('数据仓库', 4),
#  ('蓝桥杯', 4),
#  ('百度', 4),
#  ('echarts', 4),
#  ('决策树', 4),
#  ('kafka', 4),
#  ('jenkins', 4),
#  ('pygame', 4),
#  ('科技', 4),
#  ('dnn', 4),
#  ('贪心算法', 4),
#  ('adb', 3),
#  ('ssh', 3),
#  ('mvc', 3),
#  ('ci', 3),
#  ('devops', 3),
#  ('腾讯云', 3),
#  ('回归', 3),
#  ('https', 3),
#  ('产品运营', 3),
#  ('postman', 3),
#  ('原型模式', 3),
#  ('hdfs', 3),
#  ('postgresql', 3),
#  ('矩阵', 3),
#  ('scala', 3),
#  ('matplotlib', 3),
#  ('linq', 3),
#  ('系统架构', 3),
#  ('flink', 3),
#  ('单例模式', 3),
#  ('ssl', 3),
#  ('mfc', 3),
#  ('动态规划', 3),
#  ('dba', 3),
#  ('zabbix', 3),
#  ('驱动开发', 3),
#  ('mapreduce', 3),
#  ('程序人生', 3),
#  ('pycharm', 3),
#  ('线性代数', 3),
#  ('代理模式', 3),
#  ('负载均衡', 3),
#  ('宠物', 3),
#  ('uni-app', 3),
#  ('vim', 3),
#  ('clickhouse', 3),
#  ('tensorflow', 3),
#  ('金融', 2),
#  ('sqlite', 2),
#  ('pandas', 2),
#  ('中间件', 2),
#  ('交友', 2),
#  ('jquery', 2),
#  ('kotlin', 2),
#  ('支持向量机', 2),
#  ('生活', 2),
#  ('wpf', 2),
#  ('b树', 2),
#  ('webrtc', 2),
#  ('随机森林', 2),
#  ('rpc', 2),
#  ('ansible', 2),
#  ('mcu', 2),
#  ('rnn', 2),
#  ('webpack', 2),
#  ('flume', 2),
#  ('以太坊', 2),
#  ('beego', 2),
#  ('objective-c', 2),
#  ('serverless', 2),
#  ('自动驾驶', 2),
#  ('swift', 2),
#  ('java-rocketmq', 2),
#  ('散列表', 2),
#  ('制造', 2),
#  ('svn', 2),
#  ('transformer', 2),
#  ('mongodb', 2),
#  ('arcgis', 2),
#  ('eclipse', 2),
#  ('sentinel', 2),
#  ('hive', 2),
#  ('visual studio', 2),
#  ('rocketmq', 2),
#  ('tidb', 2),
#  ('去中心化', 2),
#  ('设计模式', 2),
#  ('逻辑回归', 1),
#  ('建造者模式', 1),
#  ('量子计算', 1),
#  ('tcpdump', 1),
#  ('图搜索算法', 1),
#  ('bert', 1),
#  ('nio', 1),
#  ('剪枝', 1),
#  ('hibernate', 1),
#  ('接口隔离原则', 1),
#  ('caffe', 1),
#  ('xhtml', 1),
#  ('智能家居', 1),
#  ('iphone', 1),
#  ('ar', 1),
#  ('jetty', 1),
#  ('解释器模式', 1),
#  ('能源', 1),
#  ('express', 1),
#  ('xml', 1),
#  ('备忘录模式', 1),
#  ('debian', 1),
#  ('rust', 1),
#  ('websocket', 1),
#  ('性能优化', 1),
#  ('低代码', 1),
#  ('lstm', 1),
#  ('uml', 1),
#  ('wireshark', 1),
#  ('list', 1),
#  ('动画', 1),
#  ('lua', 1),
#  ('bug', 1),
#  ('旅游', 1),
#  ('状态模式', 1),
#  ('bootstrap', 1),
#  ('paddlepaddle', 1),
#  ('gin', 1),
#  ('lvs', 1),
#  ('okhttp', 1),
#  ('里氏替换原则', 1),
#  ('pillow', 1),
#  ('交互', 1),
#  ('java-ee', 1),
#  ('sqlserver', 1),
#  ('jira', 1),
#  ('知识图谱', 1),
#  ('safari', 1),
#  ('概率论', 1),
#  ('gradle', 1),
#  ('ux', 1),
#  ('memcached', 1),
#  ('贴图', 1),
#  ('p2p', 1),
#  ('spark', 1),
#  ('经验分享', 1),
#  ('推荐算法', 1),
#  ('plotly', 1),
#  ('photoshop', 1),
#  ('gitlab', 1),
#  ('etl', 1),
#  ('proteus', 1),
#  ('jmeter', 1),
#  ('react native', 1),
#  ('ribbon', 1),
#  ('xss', 1),
#  ('ue4', 1),
#  ('perl', 1),
#  ('twitter', 1),
#  ('batch', 1),
#  ('机器人', 1),
#  ('myeclipse', 1),
#  ('harmonyos', 1),
#  ('layui', 1),
#  ('selenium', 1),
#  ('51单片机', 1),
#  ('语言模型', 1),
#  ('prometheus', 1),
#  ('jupyter', 1),
#  ('技术美术', 1)]

# %%
import pyecharts.options as opts
from pyecharts.charts import WordCloud
map = WordCloud().add(series_name="热词标签", data_pair=result, word_size_range=[6, 66]) \
    .set_global_opts(
        title_opts=opts.TitleOpts(
            title="热词标签", title_textstyle_opts=opts.TextStyleOpts(font_size=23)
        ),
        tooltip_opts=opts.TooltipOpts(is_show=True),
    )
map.render()
# 这里显示不出来。要在html文件里面才可以看到
map.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="9c50ff3dfe7b4c3891122a0ce4eff2a4" class="chart-container" style="width:900px; height:500px;"></div>
#     <script>
#         var chart_9c50ff3dfe7b4c3891122a0ce4eff2a4 = echarts.init(
#             document.getElementById('9c50ff3dfe7b4c3891122a0ce4eff2a4'), 'white', {renderer: 'canvas'});
#         var option_9c50ff3dfe7b4c3891122a0ce4eff2a4 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "wordCloud",
#             "name": "\u70ed\u8bcd\u6807\u7b7e",
#             "shape": "circle",
#             "rotationRange": [
#                 -90,
#                 90
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 6,
#                 66
#             ],
#             "data": [
#                 {
#                     "name": "\u5f00\u53d1\u8bed\u8a00",
#                     "value": 582,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(81,74,7)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "java",
#                     "value": 538,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(124,30,93)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u524d\u7aef",
#                     "value": 248,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(124,63,67)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4eba\u5de5\u667a\u80fd",
#                     "value": 244,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(129,62,47)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u8fd0\u7ef4",
#                     "value": 190,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(7,54,5)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "javascript",
#                     "value": 181,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(45,124,93)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6570\u636e\u5e93",
#                     "value": 179,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(84,1,82)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "python",
#                     "value": 171,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(70,49,7)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u670d\u52a1\u5668",
#                     "value": 169,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(43,42,103)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u7b97\u6cd5",
#                     "value": 145,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(75,70,104)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u673a\u5668\u5b66\u4e60",
#                     "value": 130,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(136,21,149)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "linux",
#                     "value": 122,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(138,155,68)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6df1\u5ea6\u5b66\u4e60",
#                     "value": 121,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(106,86,81)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5927\u6570\u636e",
#                     "value": 121,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(77,13,158)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "ecmascript",
#                     "value": 113,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(60,151,11)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "vue.js",
#                     "value": 102,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(137,21,41)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "spring",
#                     "value": 99,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(95,144,53)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u7f51\u7edc",
#                     "value": 98,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(33,156,111)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "spring boot",
#                     "value": 98,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(84,8,133)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u540e\u7aef",
#                     "value": 97,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(23,97,129)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "mybatis",
#                     "value": 88,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(98,148,143)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u795e\u7ecf\u7f51\u7edc",
#                     "value": 73,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(105,155,2)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "mysql",
#                     "value": 67,

# %%
# %%html
# <img src="https://tva1.sinaimg.cn/large/008d89Swgy1h5sqjw4lkuj30pi0dfn58.jpg"/>
# <img src="https://tva1.sinaimg.cn/large/008d89Swgy1h5sqjomcvxg30os0ean21.gif"/>
# Out:
# <img src="https://tva1.sinaimg.cn/large/008d89Swgy1h5sqjw4lkuj30pi0dfn58.jpg"/>
# <img src="https://tva1.sinaimg.cn/large/008d89Swgy1h5sqjomcvxg30os0ean21.gif"/>
